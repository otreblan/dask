# %%
import dask.dataframe as dd
import numpy as np

from dask.diagnostics import ProgressBar
from dask.distributed import LocalCluster

cluster = LocalCluster()          # Fully-featured local Dask cluster
client = cluster.get_client()

# %%
nyc_data_raw = dd.read_parquet("nyc-parking-tickets-prq")
nyc_data_raw
# Out:
# Dask DataFrame Structure:
#                 Summons Number Plate ID Registration State Plate Type Issue Date Violation Code Vehicle Body Type Vehicle Make Issuing Agency Street Code1 Street Code2 Street Code3 Vehicle Expiration Date Violation Location Violation Precinct Issuer Precinct Issuer Code Issuer Command Issuer Squad Violation Time Time First Observed Violation County Violation In Front Of Or Opposite House Number Street Name Intersecting Street Date First Observed Law Section Sub Division Violation Legal Code Days Parking In Effect     From Hours In Effect To Hours In Effect Vehicle Color Unregistered Vehicle? Vehicle Year Meter Number Feet From Curb Violation Post Code Violation Description No Standing or Stopping Violation Hydrant Violation Double Parking Violation
# npartitions=138
#                         uint32   object             object     object     object         uint16            object       object         object       uint32       uint32       uint32                  object             object            float32         float32     float32         object       object         object              object           object                            object       object      object              object              object     float32       object               object                     object               object             object        object                object      float32       object        float32              object                object                            object            object                   object
#                            ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...
# ...                        ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...
#                            ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...
#                            ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...
# Dask Name: read-parquet, 1 graph layer

# %%
with ProgressBar():
    display(nyc_data_raw["Plate ID"].head())
# Out:
# 0    GBB9093
# 1    62416MB
# 2    78755JZ
# 3    63009MA
# 4    91648MC
# Name: Plate ID, dtype: object

# %%
with ProgressBar():
    display(nyc_data_raw[["Plate ID", "Registration State"]].head())
# Out:
#   Plate ID Registration State
# 0  GBB9093                 NY
# 1  62416MB                 NY
# 2  78755JZ                 NY
# 3  63009MA                 NY
# 4  91648MC                 NY

# %%
with ProgressBar():
    display(nyc_data_raw.drop("Violation Code", axis=1).head())
# Out:
#    Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0      1283294138  GBB9093                 NY        PAS  08/04/2013
# 1      1283294151  62416MB                 NY        COM  08/04/2013
# 2      1283294163  78755JZ                 NY        COM  08/05/2013
# 3      1283294175  63009MA                 NY        COM  08/05/2013
# 4      1283294187  91648MC                 NY        COM  08/08/2013
#
#   Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  Street Code2  \
# 0              SUBN         AUDI              P         37250         13610
# 1               VAN         FORD              P         37290         40404
# 2               P-U        CHEVR              P         37030         31190
# 3               VAN         FORD              P         37270         11710
# 4              TRLR          GMC              P         37240         12010
#
#    ...  Vehicle Color Unregistered Vehicle? Vehicle Year  Meter Number  \
# 0  ...             GY                     0       2013.0             -
# 1  ...             WH                     0       2012.0             -
# 2  ...           None                     0          0.0             -
# 3  ...             WH                     0       2010.0             -
# 4  ...             BR                     0       2012.0             -
#
#    Feet From Curb  Violation Post Code Violation Description  \
# 0             0.0                 None                  None
# 1             0.0                 None                  None
# 2             0.0                 None                  None
# 3             0.0                 None                  None
# 4             0.0                 None                  None
#
#   No Standing or Stopping Violation Hydrant Violation Double Parking Violation
# 0                              None              None                     None
# 1                              None              None                     None
# 2                              None              None                     None
# 3                              None              None                     None
# 4                              None              None                     None
#
# [5 rows x 42 columns]

# %%
violationColumnNames = list(filter(lambda columnName: "Violation" in columnName, nyc_data_raw.columns))

with ProgressBar():
    display(nyc_data_raw.drop(violationColumnNames, axis=1).head())
# Out:
#    Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0      1283294138  GBB9093                 NY        PAS  08/04/2013
# 1      1283294151  62416MB                 NY        COM  08/04/2013
# 2      1283294163  78755JZ                 NY        COM  08/05/2013
# 3      1283294175  63009MA                 NY        COM  08/05/2013
# 4      1283294187  91648MC                 NY        COM  08/08/2013
#
#   Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  Street Code2  \
# 0              SUBN         AUDI              P         37250         13610
# 1               VAN         FORD              P         37290         40404
# 2               P-U        CHEVR              P         37030         31190
# 3               VAN         FORD              P         37270         11710
# 4              TRLR          GMC              P         37240         12010
#
#    ...  Law Section Sub Division  Days Parking In Effect      \
# 0  ...        408.0           F1                     BBBBBBB
# 1  ...        408.0            C                     BBBBBBB
# 2  ...        408.0           F7                     BBBBBBB
# 3  ...        408.0           F1                     BBBBBBB
# 4  ...        408.0           E1                     BBBBBBB
#
#    From Hours In Effect To Hours In Effect Vehicle Color  \
# 0                   ALL                ALL            GY
# 1                   ALL                ALL            WH
# 2                   ALL                ALL          None
# 3                   ALL                ALL            WH
# 4                   ALL                ALL            BR
#
#   Unregistered Vehicle? Vehicle Year Meter Number Feet From Curb
# 0                     0       2013.0            -            0.0
# 1                     0       2012.0            -            0.0
# 2                     0          0.0            -            0.0
# 3                     0       2010.0            -            0.0
# 4                     0       2012.0            -            0.0
#
# [5 rows x 31 columns]

# %%
nyc_data_renamed = nyc_data_raw.rename(columns={"Plate ID":"License Plate"})
nyc_data_renamed
# Out:
# Dask DataFrame Structure:
#                 Summons Number License Plate Registration State Plate Type Issue Date Violation Code Vehicle Body Type Vehicle Make Issuing Agency Street Code1 Street Code2 Street Code3 Vehicle Expiration Date Violation Location Violation Precinct Issuer Precinct Issuer Code Issuer Command Issuer Squad Violation Time Time First Observed Violation County Violation In Front Of Or Opposite House Number Street Name Intersecting Street Date First Observed Law Section Sub Division Violation Legal Code Days Parking In Effect     From Hours In Effect To Hours In Effect Vehicle Color Unregistered Vehicle? Vehicle Year Meter Number Feet From Curb Violation Post Code Violation Description No Standing or Stopping Violation Hydrant Violation Double Parking Violation
# npartitions=138
#                         uint32        object             object     object     object         uint16            object       object         object       uint32       uint32       uint32                  object             object            float32         float32     float32         object       object         object              object           object                            object       object      object              object              object     float32       object               object                     object               object             object        object                object      float32       object        float32              object                object                            object            object                   object
#                            ...           ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...
# ...                        ...           ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...
#                            ...           ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...
#                            ...           ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...
# Dask Name: rename, 2 graph layers

# %%
with ProgressBar():
    display(nyc_data_raw.loc[56].head(1))
# Out:
#     Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 56      1293090530  GES3519                 NY        PAS  07/07/2013
#
#     Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# 56              40               SDN        HONDA              F
#
#     Street Code1  ...  Vehicle Color  Unregistered Vehicle? Vehicle Year  \
# 56         70630  ...          BLACK                      0       1997.0
#
#    Meter Number  Feet From Curb  Violation Post Code  Violation Description  \
# 56            -             0.0                 None                   None
#
#    No Standing or Stopping Violation Hydrant Violation  \
# 56                              None              None
#
#    Double Parking Violation
# 56                     None
#
# [1 rows x 43 columns]

# %%
with ProgressBar():
    display(nyc_data_raw.loc[100:200].head(100))
# Out:
#      Summons Number  Plate ID Registration State Plate Type  Issue Date  \
# 100      1294727205   XBD7628                 VA        PAS  08/04/2013
# 101      1294727461   R613159                 IL        PAS  07/17/2013
# 102      1294727473   6TCX735                 CA        PAS  07/18/2013
# 103      1294727497    ZWZ43K                 NJ        PAS  08/10/2013
# 104      1295357240  T624858C                 NY        PAS  07/22/2013
# ..              ...       ...                ...        ...         ...
# 195      1307953700    481CKW                 NJ        PAS  07/27/2013
# 196      1307953724    W122KP                 NY        PAS  07/28/2013
# 197      1307953761   GAW6458                 NY        PAS  08/17/2013
# 198      1307953852   GFP6251                 NY        PAS  08/24/2013
# 199      1307953876   JGV1886                 PA        PAS  08/11/2013
#
#      Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# 100              17              SUBN         JEEP              P
# 101              17               SDN        VOLKS              P
# 102              17               SDN        MAZDA              P
# 103              17              SUBN        LINCO              P
# 104              21              SUBN        TOYOT              X
# ..              ...               ...          ...            ...
# 195              24              SUBN        NISSA              K
# 196              20               SDN        TOYOT              K
# 197              20               SDN        TOYOT              K
# 198              27               SDN        NISSA              K
# 199              20              SUBN         FORD              K
#
#      Street Code1  ...  Vehicle Color  Unregistered Vehicle? Vehicle Year  \
# 100         14510  ...            GRY                      0          0.0
# 101         14510  ...           BLUE                      0          0.0
# 102         14510  ...          BLACK                      0          0.0
# 103         14510  ...           None                      0          0.0
# 104         28790  ...          SILVE                      0       2012.0
# ..            ...  ...            ...                    ...          ...
# 195             0  ...          PURPL                      0          0.0
# 196             0  ...          MAROO                      0       1998.0
# 197         48502  ...          BLACK                      0       2001.0
# 198             0  ...            G/Y                      0       2006.0
# 199         11220  ...             GY                      0          0.0
#
#     Meter Number  Feet From Curb  Violation Post Code  Violation Description  \
# 100            -             0.0                 None                   None
# 101            -             0.0                 None                   None
# 102            -             0.0                 None                   None
# 103            -             0.0                 None                   None
# 104            -             0.0                 None                   None
# ..           ...             ...                  ...                    ...
# 195            -             0.0                 None                   None
# 196            -             0.0                 None                   None
# 197            -             0.0                 None                   None
# 198            -             0.0                 None                   None
# 199            -             0.0                 None                   None
#
#     No Standing or Stopping Violation Hydrant Violation  \
# 100                              None              None
# 101                              None              None
# 102                              None              None
# 103                              None              None
# 104                              None              None
# ..                                ...               ...
# 195                              None              None
# 196                              None              None
# 197                              None              None
# 198                              None              None
# 199                              None              None
#
#     Double Parking Violation
# 100                     None
# 101                     None
# 102                     None
# 103                     None
# 104                     None
# ..                       ...
# 195                     None
# 196                     None
# 197                     None
# 198                     None
# 199                     None
#
# [100 rows x 43 columns]

# %%
with ProgressBar():
    some_rows = nyc_data_raw.loc[100:200].head(100)

some_rows.drop(range(100, 200, 2))
# Out:
#      Summons Number  Plate ID Registration State Plate Type  Issue Date  \
# 101      1294727461   R613159                 IL        PAS  07/17/2013
# 103      1294727497    ZWZ43K                 NJ        PAS  08/10/2013
# 105      1295546486   42909JM                 NY        COM  07/17/2013
# 107      1302446484    452WW4                 MA        PAS  06/24/2013
# 109      1302453774   GEX5296                 NY        PAS  07/26/2013
# 111      1302453798    867ZFX                 CT        PAS  07/15/2013
# 113      1302456593   GEZ1408                 NY        PAS  07/15/2013
# 115      1302456738    UCSLIM                 NY        PAS  08/07/2013
# 117      1302466203   HPM2636                 PA        PAS  08/08/2013
# 119      1302466227  TWODAMAX                 NY        SRF  08/05/2013
# 121      1302466318    K39845                 NY        PAS  07/26/2013
# 123      1302466331   GJA3150                 NY        OMS  07/12/2013
# 125      1302466380   GGS5125                 NY        PAS  07/09/2013
# 127      1302466483   GEF7281                 NY        PAS  06/28/2013
# 129      1302494843   GHM9264                 NY        PAS  07/20/2013
# 131      1302494867    W36CKK                 NJ        PAS  07/20/2013
# 133      1302494934   GJA3298                 NY        OMS  07/19/2013
# 135      1302494983     RPH78                 NY        SRF  07/19/2013
# 137      1302501653   GDE3096                 NY        PAS  07/24/2013
# 139      1302511257   GFP5637                 NY        PAS  07/18/2013
# 141      1302513254   GEF7457                 NY        PAS  07/21/2013
# 143      1302870749   96272JY                 NY        COM  08/02/2013
# 145      1305400720   STN2382                 NC        PAS  08/03/2013
# 147      1306114172   91628MC                 NY        COM  08/02/2013
# 149      1306114196   62092JL                 NY        COM  08/23/2013
# 151      1306206844   55197JJ                 NY        COM  08/06/2013
# 153      1306632572   45940MD                 NY        COM  08/01/2013
# 155      1306755700    Y309CZ                 NY        PAS  08/02/2013
# 157      1306757629    561CVB                 NJ        PAS  08/06/2013
# 159      1306757861    5CA14E                 MI        PAS  08/02/2013
# 161      1306759249   GEK4279                 NY        PAS  08/02/2013
# 163      1306759262   GDL7143                 NY        PAS  08/16/2013
# 165      1306759432   JLE4572                 PA        PAS  07/23/2013
# 167      1306759481   HSW7971                 PA        PAS  07/24/2013
# 169      1306771572   WUV6389                 VA        PAS  08/19/2013
# 171      1306771596   GFF5181                 NY        PAS  08/19/2013
# 173      1306775462    P47914                 MA        COM  07/29/2013
# 175      1307045133   GFC8953                 NY        PAS  07/26/2013
# 177      1307238828   GEX4415                 NY        PAS  08/18/2013
# 179      1307452577   55003JG                 NY        COM  08/12/2013
# 181      1307452590   40470JU                 99        COM  08/12/2013
# 183      1307846646      7L6A                 NY        SRF  08/14/2013
# 185      1307935217    H50DHM                 NJ        PAS  07/30/2013
# 187      1307952574    UDV99Y                 NJ        PAS  07/21/2013
# 189      1307952987   GGW8417                 NY        PAS  07/21/2013
# 191      1307953128    N34ASW                 NJ        PAS  08/11/2013
# 193      1307953682   GGS6051                 NY        PAS  07/27/2013
# 195      1307953700    481CKW                 NJ        PAS  07/27/2013
# 197      1307953761   GAW6458                 NY        PAS  08/17/2013
# 199      1307953876   JGV1886                 PA        PAS  08/11/2013
#
#      Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# 101              17               SDN        VOLKS              P
# 103              17              SUBN        LINCO              P
# 105              19              DELV        MERCU              P
# 107              46               SDN        CHEVR              C
# 109              14               SDN        ME/BE              C
# 111              17               SDN        ACURA              C
# 113              17              SUBN        HYUND              X
# 115              17              SUBN         FORD              X
# 117              40              SUBN        CADIL              X
# 119              17               SDN        HYUND              X
# 121              17               SDN        TOYOT              X
# 123              40               SDN        CHEVR              X
# 125              17               SDN        VOLVO              X
# 127              17              None        HYUND              X
# 129              63              SUBN        ROVER              X
# 131              63               SDN        NISSA              X
# 133              63               SDN        NISSA              X
# 135              63               SDN        TOYOT              X
# 137              24              FOUR        ME/BE              X
# 139              20              SUBN        TOYOT              X
# 141              20               SDN        PONTI              X
# 143              14              DELV        MITSU              T
# 145              40              SUBN        NISSA              P
# 147              46              REFG         HINO              P
# 149              46              REFG        ISUZU              P
# 151              46              DELV         None              P
# 153              78               VAN         FORD              P
# 155              21              SUBN         None              S
# 157              21              SUBN          BMW              S
# 159              21               SDN        HONDA              S
# 161              21               SDN          BMW              S
# 163              21               SDN          BMW              S
# 165              21               SDN        NISSA              S
# 167              21              SUBN        MAZDA              S
# 169              21              SUBN          GMC              S
# 171              21              SUBN        CHEVR              S
# 173              40               VAN         FORD              S
# 175              20               SDN        HONDA              P
# 177              14               SDN        HONDA              P
# 179              46              DELV        WORKV              P
# 181              46              DELV        MERCU              P
# 183              14              TAXI        TOYOT              P
# 185              40               SDN        MITSU              K
# 187              20               SDN        CHEVR              K
# 189              63              SUBN         JEEP              K
# 191              61               SDN        CHEVR              K
# 193              24               SDN        NISSA              K
# 195              24              SUBN        NISSA              K
# 197              20               SDN        TOYOT              K
# 199              20              SUBN         FORD              K
#
#      Street Code1  ...  Vehicle Color  Unregistered Vehicle? Vehicle Year  \
# 101         14510  ...           BLUE                      0          0.0
# 103         14510  ...           None                      0          0.0
# 105         58590  ...          BROWN                      0       1996.0
# 107         75530  ...          YELLO                      0       2013.0
# 109         36420  ...          BLACK                      0          0.0
# 111             0  ...          WHITE                      0          0.0
# 113         77730  ...            BLK                      0       2013.0
# 115         77730  ...            BLK                      0       2003.0
# 117         24245  ...          SILVR                      0          0.0
# 119         53630  ...           GRAY                      0       2012.0
# 121         11700  ...           BLUE                      0          0.0
# 123         53630  ...          SILVR                      0       2013.0
# 125         53630  ...          WHITE                      0       2004.0
# 127         11800  ...           BIRG                      0       2006.0
# 129             0  ...             GY                      0       2008.0
# 131             0  ...             BK                      0          0.0
# 133             0  ...             GY                      0       2013.0
# 135             0  ...          BEIGE                      0       2005.0
# 137             0  ...          WHITE                      0       1990.0
# 139             0  ...           GRAY                      0       2012.0
# 141             0  ...          WHITE                      0       1995.0
# 143         18250  ...             WH                      0       2005.0
# 145             0  ...           GRAY                      0       2004.0
# 147         36490  ...             WH                      0       2007.0
# 149             0  ...             OR                      0       2011.0
# 151         13110  ...              W                      0       2001.0
# 153         44240  ...            WHT                      0       2013.0
# 155         52490  ...           GRAY                      0       2013.0
# 157         45990  ...            SIL                      0          0.0
# 159         53190  ...          GREEN                      0          0.0
# 161         23180  ...          BLACK                      0       2002.0
# 163         23180  ...            WHT                      0       2013.0
# 165         24540  ...            BLK                      0          0.0
# 167         24040  ...            BLK                      0       2012.0
# 169         12330  ...          WHITE                      0          0.0
# 171         12330  ...           BLUE                      0       2004.0
# 173         29890  ...            TAN                      0          0.0
# 175         61030  ...             BK                      0       1997.0
# 177         65120  ...            BLK                      0       2004.0
# 179         10010  ...          WHITE                      0       1999.0
# 181         10110  ...          WHITE                      0       2004.0
# 183         36210  ...          YELLO                      0       2010.0
# 185         45210  ...          GREEN                      0          0.0
# 187             0  ...           BLUE                      0          0.0
# 189             0  ...          BLACK                      0       2003.0
# 191             0  ...             BL                      0          0.0
# 193             0  ...           BLUE                      0       2008.0
# 195             0  ...          PURPL                      0          0.0
# 197         48502  ...          BLACK                      0       2001.0
# 199         11220  ...             GY                      0          0.0
#
#     Meter Number  Feet From Curb  Violation Post Code  Violation Description  \
# 101            -             0.0                 None                   None
# 103            -             0.0                 None                   None
# 105            -             0.0                 None                   None
# 107            -             0.0                 None                   None
# 109            -             0.0                 None                   None
# 111            -             0.0                 None                   None
# 113            -             0.0                 None                   None
# 115            -             0.0                 None                   None
# 117            -             0.0                 None                   None
# 119            -             0.0                 None                   None
# 121            -             0.0                 None                   None
# 123            -             0.0                 None                   None
# 125            -             0.0                 None                   None
# 127            -             0.0                 None                   None
# 129            -             0.0                 None                   None
# 131            -             0.0                 None                   None
# 133            -             0.0                 None                   None
# 135            -             0.0                 None                   None
# 137            -             0.0                 None                   None
# 139            -             0.0                 None                   None
# 141            -             0.0                 None                   None
# 143            -             0.0                 None                   None
# 145            -             0.0                 None                   None
# 147            -             0.0                 None                   None
# 149            -             0.0                 None                   None
# 151            -             0.0                 None                   None
# 153            -             0.0                 None                   None
# 155            -             0.0                 None                   None
# 157            -             0.0                 None                   None
# 159            -             0.0                 None                   None
# 161            -             0.0                 None                   None
# 163            -             0.0                 None                   None
# 165            -             0.0                 None                   None
# 167            -             0.0                 None                   None
# 169            -             0.0                 None                   None
# 171            -             0.0                 None                   None
# 173            -             0.0                 None                   None
# 175            -             0.0                 None                   None
# 177            -             0.0                 None                   None
# 179            -             0.0                 None                   None
# 181            -             0.0                 None                   None
# 183            -             0.0                 None                   None
# 185            -             5.0                 None                   None
# 187            -             0.0                 None                   None
# 189            -             0.0                 None                   None
# 191            -             0.0                 None                   None
# 193            -             0.0                 None                   None
# 195            -             0.0                 None                   None
# 197            -             0.0                 None                   None
# 199            -             0.0                 None                   None
#
#     No Standing or Stopping Violation Hydrant Violation  \
# 101                              None              None
# 103                              None              None
# 105                              None              None
# 107                              None              None
# 109                              None              None
# 111                              None              None
# 113                              None              None
# 115                              None              None
# 117                              None              None
# 119                              None              None
# 121                              None              None
# 123                              None              None
# 125                              None              None
# 127                              None              None
# 129                              None              None
# 131                              None              None
# 133                              None              None
# 135                              None              None
# 137                              None              None
# 139                              None              None
# 141                              None              None
# 143                              None              None
# 145                              None              None
# 147                              None              None
# 149                              None              None
# 151                              None              None
# 153                              None              None
# 155                              None              None
# 157                              None              None
# 159                              None              None
# 161                              None              None
# 163                              None              None
# 165                              None              None
# 167                              None              None
# 169                              None              None
# 171                              None              None
# 173                              None              None
# 175                              None              None
# 177                              None              None
# 179                              None              None
# 181                              None              None
# 183                              None              None
# 185                              None              None
# 187                              None              None
# 189                              None              None
# 191                              None              None
# 193                              None              None
# 195                              None              None
# 197                              None              None
# 199                              None              None
#
#     Double Parking Violation
# 101                     None
# 103                     None
# 105                     None
# 107                     None
# 109                     None
# 111                     None
# 113                     None
# 115                     None
# 117                     None
# 119                     None
# 121                     None
# 123                     None
# 125                     None
# 127                     None
# 129                     None
# 131                     None
# 133                     None
# 135                     None
# 137                     None
# 139                     None
# 141                     None
# 143                     None
# 145                     None
# 147                     None
# 149                     None
# 151                     None
# 153                     None
# 155                     None
# 157                     None
# 159                     None
# 161                     None
# 163                     None
# 165                     None
# 167                     None
# 169                     None
# 171                     None
# 173                     None
# 175                     None
# 177                     None
# 179                     None
# 181                     None
# 183                     None
# 185                     None
# 187                     None
# 189                     None
# 191                     None
# 193                     None
# 195                     None
# 197                     None
# 199                     None
#
# [50 rows x 43 columns]

# %%
missing_values = nyc_data_raw.isnull().sum()

with ProgressBar():
    percent_missing = ((missing_values/nyc_data_raw.index.size)*100).compute()

percent_missing
# Out:
# Summons Number                        0.000000
# Plate ID                              0.020867
# Registration State                    0.000000
# Plate Type                            0.000000
# Issue Date                            0.000000
# Violation Code                        0.000000
# Vehicle Body Type                     0.564922
# Vehicle Make                          0.650526
# Issuing Agency                        0.000000
# Street Code1                          0.000000
# Street Code2                          0.000000
# Street Code3                          0.000000
# Vehicle Expiration Date               0.000002
# Violation Location                   15.142846
# Violation Precinct                    0.000002
# Issuer Precinct                       0.000002
# Issuer Code                           0.000002
# Issuer Command                       15.018851
# Issuer Squad                         15.022566
# Violation Time                        0.019207
# Time First Observed                  90.040886
# Violation County                     10.154892
# Violation In Front Of Or Opposite    15.953282
# House Number                         16.932473
# Street Name                           0.054894
# Intersecting Street                  72.571941
# Date First Observed                   0.000007
# Law Section                           0.000007
# Sub Division                          0.012412
# Violation Legal Code                 84.970398
# Days Parking In Effect               23.225424
# From Hours In Effect                 44.821011
# To Hours In Effect                   44.821004
# Vehicle Color                         1.152299
# Unregistered Vehicle?                88.484122
# Vehicle Year                          0.000012
# Meter Number                         81.115883
# Feet From Curb                        0.000012
# Violation Post Code                  26.532350
# Violation Description                11.523098
# No Standing or Stopping Violation    99.999998
# Hydrant Violation                    99.999998
# Double Parking Violation             99.999998
# dtype: float64

# %%
columns_to_drop = list(percent_missing[percent_missing >= 50].index)
nyc_data_clean_stage1 = nyc_data_raw.drop(columns_to_drop, axis=1)

# %%
with ProgressBar():
    count_of_vehicle_colors = nyc_data_clean_stage1["Vehicle Color"].value_counts().compute()
    most_common_color = count_of_vehicle_colors.sort_values(ascending=False).index[0]

nyc_data_clean_stage2 = nyc_data_clean_stage1.fillna({"Vehicle Color": most_common_color})

# %%
rows_to_drop = list(percent_missing[(percent_missing > 0) & (percent_missing < 5)].index)
nyc_data_clean_stage3 = nyc_data_clean_stage2.dropna(subset=rows_to_drop)

# %%
remaining_columns_to_clean = list(percent_missing[(percent_missing >= 5) & (percent_missing < 50)].index)
nyc_data_raw.dtypes[remaining_columns_to_clean]
# Out:
# Violation Location                   object
# Issuer Command                       object
# Issuer Squad                         object
# Violation County                     object
# Violation In Front Of Or Opposite    object
# House Number                         object
# Days Parking In Effect               object
# From Hours In Effect                 object
# To Hours In Effect                   object
# Violation Post Code                  object
# Violation Description                object
# dtype: object

# %%
unknown_default_dict = dict(map(lambda name: (name, "Uknown"), remaining_columns_to_clean))

# %%
nyc_data_clean_stage4 = nyc_data_clean_stage3.fillna(unknown_default_dict)

# %%
with ProgressBar():
    print(nyc_data_clean_stage4.isnull().sum().compute())

nyc_data_clean_stage4.persist()
# Out:
# Summons Number                       0
# Plate ID                             0
# Registration State                   0
# Plate Type                           0
# Issue Date                           0
# Violation Code                       0
# Vehicle Body Type                    0
# Vehicle Make                         0
# Issuing Agency                       0
# Street Code1                         0
# Street Code2                         0
# Street Code3                         0
# Vehicle Expiration Date              0
# Violation Location                   0
# Violation Precinct                   0
# Issuer Precinct                      0
# Issuer Code                          0
# Issuer Command                       0
# Issuer Squad                         0
# Violation Time                       0
# Violation County                     0
# Violation In Front Of Or Opposite    0
# House Number                         0
# Street Name                          0
# Date First Observed                  0
# Law Section                          0
# Sub Division                         0
# Days Parking In Effect               0
# From Hours In Effect                 0
# To Hours In Effect                   0
# Vehicle Color                        0
# Vehicle Year                         0
# Feet From Curb                       0
# Violation Post Code                  0
# Violation Description                0
# dtype: int64
# Dask DataFrame Structure:
#                 Summons Number Plate ID Registration State Plate Type Issue Date Violation Code Vehicle Body Type Vehicle Make Issuing Agency Street Code1 Street Code2 Street Code3 Vehicle Expiration Date Violation Location Violation Precinct Issuer Precinct Issuer Code Issuer Command Issuer Squad Violation Time Violation County Violation In Front Of Or Opposite House Number Street Name Date First Observed Law Section Sub Division Days Parking In Effect     From Hours In Effect To Hours In Effect Vehicle Color Vehicle Year Feet From Curb Violation Post Code Violation Description
# npartitions=138
#                         uint32   object             object     object     object         uint16            object       object         object       uint32       uint32       uint32                  object             object            float32         float32     float32         object       object         object           object                            object       object      object              object     float32       object                     object               object             object        object      float32        float32              object                object
#                            ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...              ...                               ...          ...         ...                 ...         ...          ...                        ...                  ...                ...           ...          ...            ...                 ...                   ...
# ...                        ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...              ...                               ...          ...         ...                 ...         ...          ...                        ...                  ...                ...           ...          ...            ...                 ...                   ...
#                            ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...              ...                               ...          ...         ...                 ...         ...          ...                        ...                  ...                ...           ...          ...            ...                 ...                   ...
#                            ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...              ...                               ...          ...         ...                 ...         ...          ...                        ...                  ...                ...           ...          ...            ...                 ...                   ...
# Dask Name: fillna, 1 graph layer

# %%
with ProgressBar():
    licence_plate_types = nyc_data_clean_stage4["Plate Type"].value_counts().compute()

licence_plate_types
# Out:
# PAS    30452502
# COM     7966914
# OMT     1389341
# SRF      394656
# OMS      368952
#          ...
# HOU           4
# LOC           3
# JWV           3
# SNO           2
# HIF           2
# Name: Plate Type, Length: 90, dtype: int64

# %%
condition = nyc_data_clean_stage4["Plate Type"].isin(["Pas", "COM"])
plate_type_masked = nyc_data_clean_stage4["Plate Type"].where(condition, "Other")

nyc_data_recode_stage1 = nyc_data_clean_stage4.drop("Plate Type", axis=1)
nyc_data_recode_stage2 = nyc_data_recode_stage1.assign(PlateType=plate_type_masked)
nyc_data_recode_stage3 = nyc_data_recode_stage2.rename(columns={"PlateType":"Plate Type"})

# %%
with ProgressBar():
    display(nyc_data_recode_stage3["Plate Type"].value_counts().compute())
# Out:
# Other    33871088
# COM       7966914
# Name: Plate Type, dtype: int64

# %%
single_color = list(count_of_vehicle_colors[count_of_vehicle_colors == 1].index)
condition = nyc_data_clean_stage4["Vehicle Color"].isin(single_color)
vehicle_color_masked = nyc_data_clean_stage4["Vehicle Color"].mask(condition, "Other")
nyc_data_recode_stage4 = nyc_data_recode_stage3.drop("Vehicle Color", axis=1)
nyc_data_recode_stage5 = nyc_data_recode_stage4.assign(VehicleColor=vehicle_color_masked)
nyc_data_recode_stage6 = nyc_data_recode_stage5.rename(columns={"VehicleColor":"Vehicle Color"})

# %%
from datetime import datetime

issue_date_parsed = nyc_data_recode_stage6["Issue Date"].apply(lambda x: datetime.strptime(x, "%m/%d/%Y"), meta=datetime)

nyc_data_derived_stage1 = nyc_data_recode_stage6.drop("Issue Date", axis=1)
nyc_data_derived_stage2 = nyc_data_derived_stage1.assign(IssueDate=issue_date_parsed)
nyc_data_derived_stage3 = nyc_data_derived_stage2.rename(columns={"IssueDate":"Issue Date"})
# Out:
# /usr/lib/python3.11/site-packages/dask/dataframe/core.py:7047: FutureWarning: Meta is not valid, `map_partitions` and `map_overlap` expects output to be a pandas object. Try passing a pandas object as meta or a dict or tuple representing the (name, dtype) of the columns. In the future the meta you passed will not work.
#   warnings.warn(

# %%
with ProgressBar():
    display(nyc_data_derived_stage3["Issue Date"].head())
# Out:
# 0   2013-08-04
# 1   2013-08-04
# 2   2013-08-05
# 3   2013-08-05
# 4   2013-08-08
# Name: Issue Date, dtype: datetime64[ns]

# %%
issue_date_month_year = nyc_data_derived_stage3["Issue Date"].apply(lambda dt: dt.strftime("%Y%m"), meta=int)
nyc_data_derived_stage4 = nyc_data_derived_stage3.assign(IssueMonthYear=issue_date_month_year)
nyc_data_derived_stage5 = nyc_data_derived_stage4.rename(columns={"IssueMonthYear":"Citation Issued Month Year"})
# Out:
# /usr/lib/python3.11/site-packages/dask/dataframe/core.py:7047: FutureWarning: Meta is not valid, `map_partitions` and `map_overlap` expects output to be a pandas object. Try passing a pandas object as meta or a dict or tuple representing the (name, dtype) of the columns. In the future the meta you passed will not work.
#   warnings.warn(

# %%
with ProgressBar():
    display(nyc_data_derived_stage5["Citation Issued Month Year"].head())
# Out:
# 0    201308
# 1    201308
# 2    201308
# 3    201308
# 4    201308
# Name: Citation Issued Month Year, dtype: object

# %%
months = [f"{y}10" for y in range(2013, 2017+1)]
condition = nyc_data_derived_stage5["Citation Issued Month Year"].isin(months)
october_citations = nyc_data_derived_stage5[condition]

with ProgressBar():
    display(october_citations.head())
# Out:
#        Summons Number  Plate ID Registration State  Violation Code  \
# 1609       1340313923   GEK8055                 NY              40
# 23367      1351679867  XE726658                 DE              20
# 24172      1351805253   42067JM                 NY              14
# 32902      1355051060   76254JY                 NY              46
# 32903      1355051071   44125MC                 NY              46
#
#       Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  \
# 1609               SUBN        HONDA              P         79630
# 23367               P-U        DODGE              P         90980
# 24172              DELV        FRUEH              P         25630
# 32902              DELV        FRUEH              P         68020
# 32903               VAN         FORD              P         68020
#
#        Street Code2  Street Code3  ... From Hours In Effect  \
# 1609          40404         40404  ...                  ALL
# 23367             0             0  ...                  ALL
# 24172         13610         24985  ...                  ALL
# 32902         26760         66120  ...                  ALL
# 32903         26490         26520  ...                  ALL
#
#       To Hours In Effect  Vehicle Year  Feet From Curb  Violation Post Code  \
# 1609                 ALL        2013.0             5.0               Uknown
# 23367                ALL        2002.0             0.0               Uknown
# 24172                ALL        1999.0             0.0               Uknown
# 32902                ALL        2007.0             0.0               Uknown
# 32903                ALL        2011.0             0.0               Uknown
#
#       Violation Description Plate Type Vehicle Color Issue Date  \
# 1609                 Uknown      Other         BROWN 2013-10-23
# 23367                Uknown      Other           RED 2013-10-21
# 24172                Uknown        COM         WHITE 2013-10-17
# 32902                Uknown        COM         WHITE 2013-10-10
# 32903                Uknown        COM         WHITE 2013-10-10
#
#       Citation Issued Month Year
# 1609                      201310
# 23367                     201310
# 24172                     201310
# 32902                     201310
# 32903                     201310
#
# [5 rows x 36 columns]

# %%
bound_date = "2016-4-25"
condition = nyc_data_derived_stage5["Issue Date"] > bound_date
citations_after_bound = nyc_data_derived_stage5[condition]

with ProgressBar():
    display(citations_after_bound.head())
# Out:
#        Summons Number Plate ID Registration State  Violation Code  \
# 3741       1346495701  GCJ8613                 NY              20
# 3748       1346551819  GHJ2373                 NY              20
# 6905       1348077426  66811MB                 NY              78
# 12967      1353305650  91609MC                 NY              46
# 17144      1354617988  54015JV                 NY              78
#
#       Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  \
# 3741                SDN        DODGE              X         10210
# 3748               SUBN         FORD              X             0
# 6905                 IR        FRUEH              P         25680
# 12967               VAN         FORD              T         24890
# 17144               VAN         FORD              P         38590
#
#        Street Code2  Street Code3  ... From Hours In Effect  \
# 3741          19210         19250  ...                  ALL
# 3748              0             0  ...                  ALL
# 6905          46320          8120  ...                0900P
# 12967         18670         18690  ...                  ALL
# 17144         50150         52290  ...                0900P
#
#       To Hours In Effect  Vehicle Year  Feet From Curb  Violation Post Code  \
# 3741                 ALL        2010.0             0.0               Uknown
# 3748                 ALL        2010.0             0.0               Uknown
# 6905               0500A        2007.0             0.0               Uknown
# 12967                ALL        2012.0             0.0               Uknown
# 17144              0500A        2007.0             0.0               Uknown
#
#       Violation Description Plate Type Vehicle Color Issue Date  \
# 3741                 Uknown      Other           BLK 2017-08-04
# 3748                 Uknown      Other           BLK 2019-07-22
# 6905                 Uknown        COM           WHT 2053-08-02
# 12967                Uknown        COM            BR 2016-08-07
# 17144                Uknown        COM         WHITE 2032-07-28
#
#       Citation Issued Month Year
# 3741                      201708
# 3748                      201907
# 6905                      205308
# 12967                     201608
# 17144                     203207
#
# [5 rows x 36 columns]

# %%
with ProgressBar():
    condition = (nyc_data_derived_stage5["Issue Date"] > "2014-01-01") & (nyc_data_derived_stage5["Issue Date"] <= "2017-12-31")
    nyc_data_filtered = nyc_data_derived_stage5[condition]
    nyc_data_new_index = nyc_data_filtered.set_index("Citation Issued Month Year")
# Out:
# 2024-04-08 07:21:06,244 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:06,366 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:09,230 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:09,352 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:09,500 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:13,241 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:13,362 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:16,453 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:16,615 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:19,256 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:19,364 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:23,811 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:23,949 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:24,097 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:31,069 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:31,196 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:31,339 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:34,026 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:34,143 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:34,282 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:38,641 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:38,763 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:38,928 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:40,324 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:40,520 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:46,395 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:46,537 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:46,678 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:53,719 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:53,862 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:54,053 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:56,379 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:56,512 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-04-08 07:21:56,663 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-04-08 07:22:02,382 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-04-08 07:22:02,528 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-04-08 07:22:02,689 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-04-08 07:22:09,234 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-04-08 07:22:09,379 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-04-08 07:22:10,694 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-04-08 07:22:10,905 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-04-08 07:22:11,217 - distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# 2024-04-08 07:22:11,970 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2024-04-08 07:22:12,325 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-04-08 07:22:17,121 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2024-04-08 07:22:22,172 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-08 07:22:22,359 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-08 07:22:22,845 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-08 07:22:23,011 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2024-04-08 07:22:23,210 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)

# %%
years = range(2014, 2017+1)
months = range(1, 12+1)
divisions = [f"{y}{m:02d}" for y in years for m in months]

with ProgressBar():
    nyc_data_new_index.repartition(divisions=divisions) \
        .to_parquet("nyc_data_date_index")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 6
#       3 divisions = [f"{y}{m:02d}" for y in years for m in months]
#       5 with ProgressBar():
# ----> 6     nyc_data_new_index.repartition(divisions=divisions) \
#       7         .to_parquet("nyc_data_date_index")
#
# File /usr/lib/python3.11/site-packages/dask/dataframe/core.py:1602, in _Frame.repartition(self, divisions, npartitions, partition_size, freq, force)
#    1600     return repartition_npartitions(self, npartitions)
#    1601 elif divisions is not None:
# -> 1602     return repartition(self, divisions, force=force)
#    1603 elif freq is not None:
#    1604     return repartition_freq(self, freq=freq)
#
# File /usr/lib/python3.11/site-packages/dask/dataframe/core.py:7960, in repartition(df, divisions, force)
#    7958 tmp = "repartition-split-" + token
#    7959 out = "repartition-merge-" + token
# -> 7960 dsk = repartition_divisions(
#    7961     df.divisions, divisions, df._name, tmp, out, force=force
#    7962 )
#    7963 graph = HighLevelGraph.from_collections(out, dsk, dependencies=[df])
#    7964 return new_dd_object(graph, out, df._meta, divisions)
#
# File /usr/lib/python3.11/site-packages/dask/dataframe/core.py:7617, in repartition_divisions(a, b, name, out1, out2, force)
#    7615 if a[0] != b[0]:
#    7616     msg = "left side of old and new divisions are different"
# -> 7617     raise ValueError(msg)
#    7618 if a[-1] != b[-1]:
#    7619     msg = "right side of old and new divisions are different"
#
# ValueError: left side of old and new divisions are different
