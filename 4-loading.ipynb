# %% [markdown]
# # Chapter 4

# %%
import dask.dataframe as dd
import numpy as np

from dask.diagnostics import ProgressBar

dtypes = {
    'Date First Observed' : str,
    'Days Parking In Effect    ' : str,
    'Double Parking Violation' : str,
    'Feet From Curb' : np.float32,
    'From Hours In Effect' : str,
    'House Number' : str,
    'Hydrant Violation' : str,
    'Intersecting Street' : str,
    'Issue Date' : str,
    'Issuer Code' : np.float32,
    'Issuer Command' : str,
    'Issuer Precinct' : np.float32,
    'Issuer Squad' : str,
    'Issuing Agency' : str,
    'Law Section' : np.float32,
    'Meter Number' : str,
    'No Standing or Stopping Violation' : str,
    'Plate ID' : str,
    'Plate Type' : str,
    'Registration State' : str,
    'Street Code1' : np.uint32,
    'Street Code2' : np.uint32,
    'Street Code3' : np.uint32,
    'Street Name' : str,
    'Sub Division' : str,
    'Summons Number' : np.uint32,
    'Time First Observed' : str,
    'To Hours In Effect' : str,
    'Unregistered Vehicle?' : str,
    'Vehicle Body Type' : str,
    'Vehicle Color' : str,
    'Vehicle Expiration Date' : str,
    'Vehicle Make' : str,
    'Vehicle Year' : np.float32,
    'Violation Code' : np.uint16,
    'Violation County' : str,
    'Violation Description' : str,
    'Violation In Front Of Or Opposite' : str,
    'Violation Legal Code' : str,
    'Violation Location' : str,
    'Violation Post Code' : str,
    'Violation Precinct' : np.float32,
    'Violation Time': str
}


def read_parking_csv(path: str):
    return dd.read_csv(path, dtype=dtypes)

fy14 = read_parking_csv("Parking_Violations_Issued_-_Fiscal_Year_2014__August_2013___June_2014_.csv")
fy15 = read_parking_csv("Parking_Violations_Issued_-_Fiscal_Year_2015.csv")
fy16 = read_parking_csv("Parking_Violations_Issued_-_Fiscal_Year_2016.csv")
fy17 = read_parking_csv("Parking_Violations_Issued_-_Fiscal_Year_2017.csv")

fy17
# Out:
# Dask DataFrame Structure:
#                Summons Number Plate ID Registration State Plate Type Issue Date Violation Code Vehicle Body Type Vehicle Make Issuing Agency Street Code1 Street Code2 Street Code3 Vehicle Expiration Date Violation Location Violation Precinct Issuer Precinct Issuer Code Issuer Command Issuer Squad Violation Time Time First Observed Violation County Violation In Front Of Or Opposite House Number Street Name Intersecting Street Date First Observed Law Section Sub Division Violation Legal Code Days Parking In Effect     From Hours In Effect To Hours In Effect Vehicle Color Unregistered Vehicle? Vehicle Year Meter Number Feet From Curb Violation Post Code Violation Description No Standing or Stopping Violation Hydrant Violation Double Parking Violation
# npartitions=32
#                        uint32   object             object     object     object         uint16            object       object         object       uint32       uint32       uint32                  object             object            float32         float32     float32         object       object         object              object           object                            object       object      object              object              object     float32       object               object                     object               object             object        object                object      float32       object        float32              object                object                            object            object                   object
#                           ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...
# ...                       ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...
#                           ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...
#                           ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...
# Dask Name: read-csv, 1 graph layer

# %%
fy17.columns
# Out:
# Index(['Summons Number', 'Plate ID', 'Registration State', 'Plate Type',
#        'Issue Date', 'Violation Code', 'Vehicle Body Type', 'Vehicle Make',
#        'Issuing Agency', 'Street Code1', 'Street Code2', 'Street Code3',
#        'Vehicle Expiration Date', 'Violation Location', 'Violation Precinct',
#        'Issuer Precinct', 'Issuer Code', 'Issuer Command', 'Issuer Squad',
#        'Violation Time', 'Time First Observed', 'Violation County',
#        'Violation In Front Of Or Opposite', 'House Number', 'Street Name',
#        'Intersecting Street', 'Date First Observed', 'Law Section',
#        'Sub Division', 'Violation Legal Code', 'Days Parking In Effect    ',
#        'From Hours In Effect', 'To Hours In Effect', 'Vehicle Color',
#        'Unregistered Vehicle?', 'Vehicle Year', 'Meter Number',
#        'Feet From Curb', 'Violation Post Code', 'Violation Description',
#        'No Standing or Stopping Violation', 'Hydrant Violation',
#        'Double Parking Violation'],
#       dtype='object')

# %%
from functools import reduce

columns = [
    set(fy14.columns),
    set(fy15.columns),
    set(fy16.columns),
    set(fy17.columns),
]

common_columns = list(reduce(lambda a, i: a.intersection(i), columns))
common_columns
# Out:
# ['Street Code2',
#  'Violation Post Code',
#  'Vehicle Year',
#  'Violation Location',
#  'Date First Observed',
#  'Issuer Squad',
#  'Intersecting Street',
#  'Vehicle Color',
#  'Plate Type',
#  'To Hours In Effect',
#  'Plate ID',
#  'Law Section',
#  'Street Code3',
#  'Summons Number',
#  'Feet From Curb',
#  'Issuer Code',
#  'Double Parking Violation',
#  'House Number',
#  'Issue Date',
#  'Violation In Front Of Or Opposite',
#  'Issuer Precinct',
#  'Violation Precinct',
#  'Violation Code',
#  'Vehicle Body Type',
#  'Violation Legal Code',
#  'Registration State',
#  'Sub Division',
#  'Days Parking In Effect    ',
#  'Vehicle Make',
#  'Issuer Command',
#  'Violation County',
#  'Hydrant Violation',
#  'Meter Number',
#  'Issuing Agency',
#  'Violation Time',
#  'Street Name',
#  'Street Code1',
#  'Time First Observed',
#  'Vehicle Expiration Date',
#  'From Hours In Effect',
#  'Unregistered Vehicle?',
#  'No Standing or Stopping Violation',
#  'Violation Description']

# %%
fy17[common_columns].head()
# Out:
#    Street Code2 Violation Post Code  Vehicle Year Violation Location  \
# 0             0                 NaN        2001.0                NaN
# 1             0                 NaN        2001.0                NaN
# 2             0                 NaN        2004.0                NaN
# 3         34330                  04        2007.0               0014
# 4         34310                31 6        2007.0               0013
#
#   Date First Observed Issuer Squad Intersecting Street Vehicle Color  \
# 0                   0          NaN          BARNES AVE            GY
# 1                   0          NaN          BARNES AVE            GY
# 2                   0          NaN             94TH ST            BK
# 3                   0            J                 NaN            WH
# 4                   0            M                 NaN         WHITE
#
#   Plate Type To Hours In Effect  ... Issuing Agency  Violation Time  \
# 0        PAS                NaN  ...              V           0143A
# 1        PAS                NaN  ...              V           0400P
# 2        PAS                NaN  ...              V           0233P
# 3        COM              0700P  ...              T           1120A
# 4        COM              0700P  ...              T           0555P
#
#             Street Name  Street Code1  Time First Observed  \
# 0  ALLERTON AVE (W/B) @             0                  NaN
# 1  ALLERTON AVE (W/B) @             0                  NaN
# 2  SB WEBSTER AVE @ E 1             0                  NaN
# 3               7th Ave         10610                  NaN
# 4               6th Ave         10510                  NaN
#
#    Vehicle Expiration Date From Hours In Effect Unregistered Vehicle?  \
# 0                        0                  NaN                   NaN
# 1                        0                  NaN                   NaN
# 2                        0                  NaN                   NaN
# 3                 20180630                0700A                   NaN
# 4                 20170228                0700A                   NaN
#
#   No Standing or Stopping Violation          Violation Description
# 0                               NaN   FAILURE TO STOP AT RED LIGHT
# 1                               NaN   FAILURE TO STOP AT RED LIGHT
# 2                               NaN             BUS LANE VIOLATION
# 3                               NaN          47-Double PKG-Midtown
# 4                               NaN  69-Failure to Disp Muni Recpt
#
# [5 rows x 43 columns]

# %%
data = dd.read_csv("Parking_Violations*.csv", dtype=dtypes, usecols=common_columns)

# %%
with ProgressBar():
    data.to_parquet("nyc-parking-tickets-prq")
# Out:
# [########################################] | 100% Completed | 294.29 s
